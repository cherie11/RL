# %% [markdown]
# # Model-Based RL
# In this exercise you will implement a policy and model network which work in tandem to solve the CartPole reinforcement learning problem.

# %% [markdown]
# What is a model and why would we want to use one? In this case, a model is going to be a neural network that attempts to learn the dynamics of the real environment. For example, in the CartPole we would like a model to be able to predict the next position of the Cart given the previous position and an action. By learning an accurate model, we can train our agent using the model rather than requiring to use the real environment every time. While this may seem less useful when the real environment is itself a simulation, like in our CartPole task, it can have huge advantages when attempting to learn policies for acting in the physical world.

# %% [markdown]
# How are we going to accomplish this in Tensorflow? We are going to be using a neural network that will learn the transition dynamics between a previous observation and action, and the expected new observation, reward, and done state. Our training procedure will involve switching between training our model using the real environment, and training our agent’s policy using the model environment. By using this approach we will be able to learn a policy that allows our agent to solve the CartPole task without actually ever training the policy on the real environment!

# %% [markdown]
# ### Loading libraries and starting CartPole environment

# %%
from __future__ import print_function
import numpy as np
try:
    import cPickle as pickle
except:
    import pickle
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
import math

# %%
import sys
if sys.version_info.major > 2:
    xrange = range
del sys

# %%
import gym
env = gym.make('CartPole-v0')

# %% [markdown]
# ### Setting Hyper-parameters

# %%
# hyperparameters
H = 8 # number of hidden layer neurons
learning_rate = 1e-2
gamma = 0.99 # discount factor for reward
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2
resume = False # resume from previous checkpoint?

model_bs = 3 # Batch size when learning from model
real_bs = 3 # Batch size when learning from real environment

# model initialization
D = 4 # input dimensionality

# %% [markdown]
# ### Policy Network

# %%
tf.reset_default_graph()
observations = tf.placeholder(tf.float32, [None,4] , name="input_x")
W1 = tf.get_variable("W1", shape=[4, H],
           initializer=tf.contrib.layers.xavier_initializer())
layer1 = tf.nn.relu(tf.matmul(observations,W1))
W2 = tf.get_variable("W2", shape=[H, 1],
           initializer=tf.contrib.layers.xavier_initializer())
score = tf.matmul(layer1,W2)
probability = tf.nn.sigmoid(score)

tvars = tf.trainable_variables()
input_y = tf.placeholder(tf.float32,[None,1], name="input_y")
advantages = tf.placeholder(tf.float32,name="reward_signal")
adam = tf.train.AdamOptimizer(learning_rate=learning_rate)
W1Grad = tf.placeholder(tf.float32,name="batch_grad1")
W2Grad = tf.placeholder(tf.float32,name="batch_grad2")
batchGrad = [W1Grad,W2Grad]

################################################################################
# TODO: Implement the loss function.                                           #
# This sends the weights in the direction of making actions that gave good     #
# advantage (reward overtime) more likely, and actions that didn't less likely.#
################################################################################
logp=tf.log((input_y)*(input_y-probability)+(1-input_y)*(input_y+probability))
loss=-tf.reduce_mean(advantages*logp)

################################################################################
#                                 END OF YOUR CODE                             #
################################################################################

newGrads = tf.gradients(loss,tvars)
updateGrads = adam.apply_gradients(zip(batchGrad,tvars))

# %% [markdown]
# ### Model Network
# Here we implement a multi-layer neural network that predicts the next observation, reward, and done state from a current state and action.

# %%
mH = 256 # model layer size

input_data = tf.placeholder(tf.float32, [None, 5])
with tf.variable_scope('rnnlm'):
    softmax_w = tf.get_variable("softmax_w", [mH, 50])
    softmax_b = tf.get_variable("softmax_b", [50])

previous_state = tf.placeholder(tf.float32, [None,5] , name="previous_state")
W1M = tf.get_variable("W1M", shape=[5, mH],
           initializer=tf.contrib.layers.xavier_initializer())
B1M = tf.Variable(tf.zeros([mH]),name="B1M")
layer1M = tf.nn.relu(tf.matmul(previous_state,W1M) + B1M)
W2M = tf.get_variable("W2M", shape=[mH, mH],
           initializer=tf.contrib.layers.xavier_initializer())
B2M = tf.Variable(tf.zeros([mH]),name="B2M")
layer2M = tf.nn.relu(tf.matmul(layer1M,W2M) + B2M)
wO = tf.get_variable("wO", shape=[mH, 4],
           initializer=tf.contrib.layers.xavier_initializer())
wR = tf.get_variable("wR", shape=[mH, 1],
           initializer=tf.contrib.layers.xavier_initializer())
wD = tf.get_variable("wD", shape=[mH, 1],
           initializer=tf.contrib.layers.xavier_initializer())

bO = tf.Variable(tf.zeros([4]),name="bO")
bR = tf.Variable(tf.zeros([1]),name="bR")
bD = tf.Variable(tf.ones([1]),name="bD")


predicted_observation = tf.matmul(layer2M,wO,name="predicted_observation") + bO
predicted_reward = tf.matmul(layer2M,wR,name="predicted_reward") + bR
predicted_done = tf.sigmoid(tf.matmul(layer2M,wD,name="predicted_done") + bD)

true_observation = tf.placeholder(tf.float32,[None,4],name="true_observation")
true_reward = tf.placeholder(tf.float32,[None,1],name="true_reward")
true_done = tf.placeholder(tf.float32,[None,1],name="true_done")


predicted_state = tf.concat([predicted_observation,predicted_reward,predicted_done],1)

observation_loss = tf.square(true_observation - predicted_observation)

reward_loss = tf.square(true_reward - predicted_reward)

done_loss = tf.multiply(predicted_done, true_done) + tf.multiply(1-predicted_done, 1-true_done)
done_loss = -tf.log(done_loss)

model_loss = tf.reduce_mean(observation_loss + done_loss + reward_loss)

modelAdam = tf.train.AdamOptimizer(learning_rate=learning_rate)
updateModel = modelAdam.minimize(model_loss)

# %% [markdown]
# ### Helper-functions

# %%
def resetGradBuffer(gradBuffer):
    for ix,grad in enumerate(gradBuffer):
        gradBuffer[ix] = grad * 0
    return gradBuffer

def discount_rewards(r):
    ################################################################################
    # TODO: Implement the discounted rewards function                              #
    # Return discounted rewards weighed by gamma. Each reward will be replaced     #
    # with a weight reward that involves itself and all the other rewards occuring #
    # after it. The later the reward after it happens, the less effect it has on   #
    # the current rewards's discounted reward                                      #
    # Hint: [r0, r1, r2, ..., r_N] will look someting like:                        #
    #       [(r0 + r1*gamma^1 + ... r_N*gamma^N), (r1 + r2*gamma^1 + ...), ...]    #
    ################################################################################
    discounted = np.zeros_like(r)
    running_add = 0
    for t in reversed(xrange(0, r.size)):
        running_add = running_add*gamma+r[t]
        discounted[t] = running_add
    return discounted  
    ################################################################################
    #                                 END OF YOUR CODE                             #
    ################################################################################

# This function uses our model to produce a new state when given a previous state and action
def stepModel(sess, xs, action):
    toFeed = np.reshape(np.hstack([xs[-1][0],np.array(action)]),[1,5])
    myPredict = sess.run([predicted_state],feed_dict={previous_state: toFeed})
    reward = myPredict[0][:,4]
    observation = myPredict[0][:,0:4]
    observation[:,0] = np.clip(observation[:,0],-2.4,2.4)
    observation[:,2] = np.clip(observation[:,2],-0.4,0.4)
    doneP = np.clip(myPredict[0][:,5],0,1)
    if doneP > 0.1 or len(xs)>= 300:
        done = True
    else:
        done = False
    return observation, reward, done

# %% [markdown]
# ## Training the Policy and Model

# %%
xs,drs,ys,ds = [],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 1
real_episodes = 1
init = tf.global_variables_initializer()
batch_size = real_bs

drawFromModel = False # When set to True, will use model for observations
trainTheModel = True # Whether to train the model
trainThePolicy = False # Whether to train the policy
switch_point = 1

# Launch the graph
with tf.Session() as sess:
    rendering = False
    sess.run(init)
    observation = env.reset()
    x = observation
    gradBuffer = sess.run(tvars)
    gradBuffer = resetGradBuffer(gradBuffer)
    
    while episode_number <= 5000:
        # Start displaying environment once performance is acceptably high.
        if (reward_sum/batch_size > 150 and drawFromModel == False) or rendering == True : 
            env.render()
            rendering = True
            
        x = np.reshape(observation,[1,4])

        tfprob = sess.run(probability,feed_dict={observations: x})
        action = 1 if np.random.uniform() < tfprob else 0

        # record various intermediates (needed later for backprop)
        xs.append(x) 
        y = 1 if action == 0 else 0 
        ys.append(y)
        
        # step the  model or real environment and get new measurements
        if drawFromModel == False:
            observation, reward, done, info = env.step(action)
        else:
            observation, reward, done = stepModel(sess,xs,action)
                
        reward_sum += reward
        
        ds.append(done*1)

        drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

        if done: 
            
            if drawFromModel == False: 
                real_episodes += 1
            episode_number += 1

            # stack together all inputs, hidden states, action gradients, and rewards for this episode
            epx = np.vstack(xs)
            epy = np.vstack(ys)
            epr = np.vstack(drs)
            epd = np.vstack(ds)
            xs,drs,ys,ds = [],[],[],[] # reset array memory
            
            if trainTheModel == True:
                
                ################################################################################
                # TODO: Run the model network and compute predicted_state                      #
                # Output: 'pState'                                                             #
                ################################################################################
                preStates=epx[:-1]
                nextStates=epx[1:]
              

                actions=-1*(epy[:-1]-1)
                rewards = epr[1:]
                dones = epd[1:]
                feed_dict={previous_state:np.hstack([preStates,actions]), true_observation: nextStates,true_done:dones,true_reward:rewards}
                state_nextsAll = np.hstack([nextStates,rewards,dones])
                # compute the loss & update the model & predict the state
                pState,_ = sess.run([predicted_state,updateModel],feed_dict)
                
                ################################################################################
                #                                 END OF YOUR CODE                             #
                ################################################################################
                

            if trainThePolicy == True:
                
                ################################################################################
                # TODO: Run the policy network and compute newGrads                            #
                # Output: 'tGrad'                                                              #
                ################################################################################
                depr = discount_rewards(epr).astype('float32')
                
                depr-=np.mean(depr)
                depr/=np.std(depr)
                tGrad=sess.run(newGrads,feed_dict={observations:epx,input_y:epy,advantages:depr})
                ################################################################################
                #                                 END OF YOUR CODE                             #
                ################################################################################
                
                # If gradients becom too large, end training process
                if np.sum(tGrad[0] == tGrad[0]) == 0:
                    print("Grad too large")
                    break
                for ix,grad in enumerate(tGrad):
                    gradBuffer[ix] += grad
                
            if switch_point + batch_size == episode_number: 
                switch_point = episode_number
                if trainThePolicy == True:
                    
                    ################################################################################
                    # TODO:                                                                        #
                    # (1) Run the policy network and update gradients                              #
                    # (2) Reset gradBuffer to 0                                                    #
                    ################################################################################
              
                    feed_dict={W1Grad:gradBuffer[0],W2Grad:gradBuffer[1]}
                    sess.run(updateGrads, feed_dict=feed_dict)
                    gradBuffer=resetGradBuffer(gradBuffer)                 
                    ################################################################################
                    #                                 END OF YOUR CODE                             #
                    ################################################################################
               
                running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
                if drawFromModel == False:
                    print('World Perf: Episode %f. Reward %f. action: %f. mean reward %f.' % (real_episodes,reward_sum/real_bs,action, running_reward/real_bs))
                    if reward_sum/batch_size > 200:
                        print("Complete!")
                        break
                reward_sum = 0

                # Once the model has been trained on 100 episodes
                if episode_number > 100:
                    
                    ################################################################################
                    # TODO: Alternating between training the policy from the model and training    #
                    # the model from the real environment.                                         #
                    ################################################################################
                    drawFromModel = not drawFromModel
                    trainTheModel = not trainTheModel
                    trainThePolicy = not trainThePolicy
                    ################################################################################
                    #                                 END OF YOUR CODE                             #
                    ################################################################################
            
            if drawFromModel == True:
                observation = np.random.uniform(-0.1,0.1,[4]) # Generate reasonable starting point
                batch_size = model_bs
            else:
                observation = env.reset()
                batch_size = real_bs
                
print(real_episodes)
# Out:
# World Perf: Episode 4.000000. Reward 26.666667. action: 1.000000. mean reward 26.666667.
# World Perf: Episode 7.000000. Reward 15.000000. action: 1.000000. mean reward 26.550000.
# World Perf: Episode 10.000000. Reward 46.333333. action: 0.000000. mean reward 26.747833.
# World Perf: Episode 13.000000. Reward 22.666667. action: 0.000000. mean reward 26.707022.
# World Perf: Episode 16.000000. Reward 26.666667. action: 1.000000. mean reward 26.706618.
# World Perf: Episode 19.000000. Reward 31.000000. action: 0.000000. mean reward 26.749552.
# World Perf: Episode 22.000000. Reward 63.666667. action: 1.000000. mean reward 27.118723.
# World Perf: Episode 25.000000. Reward 24.333333. action: 1.000000. mean reward 27.090869.
# World Perf: Episode 28.000000. Reward 27.333333. action: 0.000000. mean reward 27.093294.
# World Perf: Episode 31.000000. Reward 18.666667. action: 0.000000. mean reward 27.009028.
# World Perf: Episode 34.000000. Reward 24.666667. action: 1.000000. mean reward 26.985604.
# World Perf: Episode 37.000000. Reward 26.333333. action: 0.000000. mean reward 26.979081.
# World Perf: Episode 40.000000. Reward 36.666667. action: 1.000000. mean reward 27.075957.
# World Perf: Episode 43.000000. Reward 31.666667. action: 1.000000. mean reward 27.121864.
# World Perf: Episode 46.000000. Reward 25.000000. action: 0.000000. mean reward 27.100646.
# World Perf: Episode 49.000000. Reward 22.666667. action: 0.000000. mean reward 27.056306.
# World Perf: Episode 52.000000. Reward 24.333333. action: 0.000000. mean reward 27.029076.
# World Perf: Episode 55.000000. Reward 29.666667. action: 1.000000. mean reward 27.055452.
# World Perf: Episode 58.000000. Reward 16.333333. action: 1.000000. mean reward 26.948231.
# World Perf: Episode 61.000000. Reward 18.666667. action: 0.000000. mean reward 26.865415.
# World Perf: Episode 64.000000. Reward 28.000000. action: 0.000000. mean reward 26.876761.
# World Perf: Episode 67.000000. Reward 30.000000. action: 0.000000. mean reward 26.907993.
# World Perf: Episode 70.000000. Reward 39.666667. action: 0.000000. mean reward 27.035580.
# World Perf: Episode 73.000000. Reward 26.000000. action: 1.000000. mean reward 27.025224.
# World Perf: Episode 76.000000. Reward 24.000000. action: 0.000000. mean reward 26.994972.
# World Perf: Episode 79.000000. Reward 28.333333. action: 1.000000. mean reward 27.008356.
# World Perf: Episode 82.000000. Reward 36.000000. action: 0.000000. mean reward 27.098272.
# World Perf: Episode 85.000000. Reward 16.333333. action: 1.000000. mean reward 26.990623.
# World Perf: Episode 88.000000. Reward 26.666667. action: 0.000000. mean reward 26.987383.
# World Perf: Episode 91.000000. Reward 16.333333. action: 0.000000. mean reward 26.880843.
# World Perf: Episode 94.000000. Reward 32.666667. action: 1.000000. mean reward 26.938701.
# World Perf: Episode 97.000000. Reward 21.000000. action: 0.000000. mean reward 26.879314.
# World Perf: Episode 100.000000. Reward 29.666667. action: 0.000000. mean reward 26.907187.
# World Perf: Episode 103.000000. Reward 25.333333. action: 0.000000. mean reward 26.891449.
# World Perf: Episode 106.000000. Reward 61.666667. action: 0.000000. mean reward 27.300768.
# World Perf: Episode 109.000000. Reward 23.666667. action: 1.000000. mean reward 27.171835.
# World Perf: Episode 112.000000. Reward 26.666667. action: 0.000000. mean reward 26.956406.
# World Perf: Episode 115.000000. Reward 17.333333. action: 0.000000. mean reward 26.711527.
# World Perf: Episode 118.000000. Reward 28.333333. action: 0.000000. mean reward 26.624449.
# World Perf: Episode 121.000000. Reward 14.333333. action: 0.000000. mean reward 26.467489.
# World Perf: Episode 124.000000. Reward 20.333333. action: 1.000000. mean reward 26.244608.
# World Perf: Episode 127.000000. Reward 23.333333. action: 1.000000. mean reward 26.121239.
# World Perf: Episode 130.000000. Reward 35.666667. action: 0.000000. mean reward 26.292162.
# World Perf: Episode 133.000000. Reward 43.333333. action: 0.000000. mean reward 26.309029.
# World Perf: Episode 136.000000. Reward 25.000000. action: 0.000000. mean reward 26.074919.
# World Perf: Episode 139.000000. Reward 23.666667. action: 0.000000. mean reward 25.856316.
# World Perf: Episode 142.000000. Reward 28.000000. action: 0.000000. mean reward 25.740273.
# World Perf: Episode 145.000000. Reward 32.000000. action: 0.000000. mean reward 25.968512.
# World Perf: Episode 148.000000. Reward 20.666667. action: 0.000000. mean reward 25.713713.
# World Perf: Episode 151.000000. Reward 34.333333. action: 1.000000. mean reward 25.610764.
# World Perf: Episode 154.000000. Reward 23.333333. action: 0.000000. mean reward 25.392611.
# World Perf: Episode 157.000000. Reward 32.000000. action: 0.000000. mean reward 25.390779.
# World Perf: Episode 160.000000. Reward 39.666667. action: 0.000000. mean reward 25.408556.
# World Perf: Episode 163.000000. Reward 53.666667. action: 1.000000. mean reward 25.570623.
# World Perf: Episode 166.000000. Reward 19.666667. action: 1.000000. mean reward 28.126905.
# World Perf: Episode 169.000000. Reward 26.666667. action: 1.000000. mean reward 27.907236.
# World Perf: Episode 172.000000. Reward 46.333333. action: 1.000000. mean reward 27.893616.
# World Perf: Episode 175.000000. Reward 26.333333. action: 1.000000. mean reward 27.709145.
# World Perf: Episode 178.000000. Reward 44.666667. action: 0.000000. mean reward 27.746771.
# World Perf: Episode 181.000000. Reward 23.000000. action: 1.000000. mean reward 28.591825.
# World Perf: Episode 184.000000. Reward 28.333333. action: 1.000000. mean reward 31.319284.
# World Perf: Episode 187.000000. Reward 26.000000. action: 1.000000. mean reward 31.371582.
# World Perf: Episode 190.000000. Reward 39.333333. action: 1.000000. mean reward 31.902956.
# World Perf: Episode 193.000000. Reward 38.000000. action: 1.000000. mean reward 34.611362.
# World Perf: Episode 196.000000. Reward 24.333333. action: 0.000000. mean reward 34.710453.
# World Perf: Episode 199.000000. Reward 52.666667. action: 1.000000. mean reward 34.719563.
# World Perf: Episode 202.000000. Reward 23.000000. action: 0.000000. mean reward 34.359207.
# World Perf: Episode 205.000000. Reward 20.666667. action: 0.000000. mean reward 35.236904.
# World Perf: Episode 208.000000. Reward 43.333333. action: 1.000000. mean reward 35.487286.
# World Perf: Episode 211.000000. Reward 41.666667. action: 1.000000. mean reward 35.314785.
# World Perf: Episode 214.000000. Reward 40.000000. action: 0.000000. mean reward 35.144691.
# World Perf: Episode 217.000000. Reward 22.000000. action: 1.000000. mean reward 36.572887.
# World Perf: Episode 220.000000. Reward 33.000000. action: 0.000000. mean reward 36.315472.
# World Perf: Episode 223.000000. Reward 28.000000. action: 0.000000. mean reward 37.270638.
# World Perf: Episode 226.000000. Reward 38.000000. action: 0.000000. mean reward 37.242634.
# World Perf: Episode 229.000000. Reward 39.333333. action: 1.000000. mean reward 36.958576.
# World Perf: Episode 232.000000. Reward 48.000000. action: 1.000000. mean reward 36.959461.
# World Perf: Episode 235.000000. Reward 33.666667. action: 1.000000. mean reward 36.941166.
# World Perf: Episode 238.000000. Reward 49.333333. action: 1.000000. mean reward 36.963737.
# World Perf: Episode 241.000000. Reward 30.666667. action: 1.000000. mean reward 36.698997.
# World Perf: Episode 244.000000. Reward 38.333333. action: 1.000000. mean reward 36.577377.
# World Perf: Episode 247.000000. Reward 59.666667. action: 1.000000. mean reward 38.412937.
# World Perf: Episode 250.000000. Reward 35.333333. action: 0.000000. mean reward 38.103516.
# World Perf: Episode 253.000000. Reward 52.333333. action: 1.000000. mean reward 37.925922.
# World Perf: Episode 256.000000. Reward 53.000000. action: 1.000000. mean reward 37.808868.
# World Perf: Episode 259.000000. Reward 42.333333. action: 0.000000. mean reward 38.163078.
# World Perf: Episode 262.000000. Reward 28.333333. action: 1.000000. mean reward 37.794960.
# World Perf: Episode 265.000000. Reward 20.000000. action: 0.000000. mean reward 37.309231.
# World Perf: Episode 268.000000. Reward 37.000000. action: 0.000000. mean reward 37.006084.
# World Perf: Episode 271.000000. Reward 39.000000. action: 1.000000. mean reward 36.766090.
# World Perf: Episode 274.000000. Reward 36.333333. action: 0.000000. mean reward 36.567326.
# World Perf: Episode 277.000000. Reward 60.666667. action: 1.000000. mean reward 36.927776.
# World Perf: Episode 280.000000. Reward 34.333333. action: 0.000000. mean reward 36.729412.
# World Perf: Episode 283.000000. Reward 35.666667. action: 0.000000. mean reward 38.150887.
# World Perf: Episode 286.000000. Reward 34.333333. action: 0.000000. mean reward 39.112164.
# World Perf: Episode 289.000000. Reward 48.333333. action: 1.000000. mean reward 38.887894.
# World Perf: Episode 292.000000. Reward 28.000000. action: 0.000000. mean reward 38.685940.
# World Perf: Episode 295.000000. Reward 28.000000. action: 1.000000. mean reward 39.981182.
# World Perf: Episode 298.000000. Reward 44.333333. action: 1.000000. mean reward 39.720425.
# World Perf: Episode 301.000000. Reward 43.333333. action: 1.000000. mean reward 40.143898.
# World Perf: Episode 304.000000. Reward 29.000000. action: 1.000000. mean reward 40.260960.
# World Perf: Episode 307.000000. Reward 55.666667. action: 1.000000. mean reward 40.170090.
# World Perf: Episode 310.000000. Reward 20.333333. action: 1.000000. mean reward 40.134857.
# World Perf: Episode 313.000000. Reward 60.666667. action: 0.000000. mean reward 40.159073.
# World Perf: Episode 316.000000. Reward 33.333333. action: 1.000000. mean reward 39.805717.
# World Perf: Episode 319.000000. Reward 47.333333. action: 0.000000. mean reward 39.759590.
# World Perf: Episode 322.000000. Reward 51.333333. action: 0.000000. mean reward 39.620495.
# World Perf: Episode 325.000000. Reward 50.000000. action: 1.000000. mean reward 40.515659.
# World Perf: Episode 328.000000. Reward 33.000000. action: 1.000000. mean reward 40.687031.
# World Perf: Episode 331.000000. Reward 22.000000. action: 1.000000. mean reward 42.331814.
# World Perf: Episode 334.000000. Reward 58.333333. action: 0.000000. mean reward 44.978481.
# World Perf: Episode 337.000000. Reward 36.666667. action: 0.000000. mean reward 44.513931.
# World Perf: Episode 340.000000. Reward 65.666667. action: 0.000000. mean reward 44.373463.
# World Perf: Episode 343.000000. Reward 49.000000. action: 0.000000. mean reward 44.093140.
# World Perf: Episode 346.000000. Reward 68.333333. action: 0.000000. mean reward 44.491928.
# World Perf: Episode 349.000000. Reward 43.333333. action: 1.000000. mean reward 45.602283.
# World Perf: Episode 352.000000. Reward 34.333333. action: 0.000000. mean reward 47.844070.
# World Perf: Episode 355.000000. Reward 30.000000. action: 0.000000. mean reward 47.281097.
# World Perf: Episode 358.000000. Reward 42.666667. action: 1.000000. mean reward 47.311417.
# World Perf: Episode 361.000000. Reward 49.333333. action: 1.000000. mean reward 49.971725.
# World Perf: Episode 364.000000. Reward 19.666667. action: 1.000000. mean reward 51.451221.
# World Perf: Episode 367.000000. Reward 58.333333. action: 1.000000. mean reward 53.856720.
# World Perf: Episode 370.000000. Reward 35.333333. action: 1.000000. mean reward 53.282818.
# World Perf: Episode 373.000000. Reward 31.000000. action: 1.000000. mean reward 53.002567.
# World Perf: Episode 376.000000. Reward 23.000000. action: 1.000000. mean reward 52.248142.
# World Perf: Episode 379.000000. Reward 48.333333. action: 0.000000. mean reward 52.543056.
# World Perf: Episode 382.000000. Reward 41.000000. action: 1.000000. mean reward 51.997467.
# World Perf: Episode 385.000000. Reward 55.333333. action: 1.000000. mean reward 54.430756.
# World Perf: Episode 388.000000. Reward 65.666667. action: 0.000000. mean reward 54.890064.
# World Perf: Episode 391.000000. Reward 41.666667. action: 0.000000. mean reward 57.164013.
# World Perf: Episode 394.000000. Reward 53.000000. action: 0.000000. mean reward 58.405651.
# World Perf: Episode 397.000000. Reward 52.000000. action: 1.000000. mean reward 58.151020.
# World Perf: Episode 400.000000. Reward 33.333333. action: 1.000000. mean reward 59.594799.
# World Perf: Episode 403.000000. Reward 38.666667. action: 1.000000. mean reward 59.153561.
# World Perf: Episode 406.000000. Reward 61.666667. action: 0.000000. mean reward 58.735050.
# World Perf: Episode 409.000000. Reward 40.000000. action: 0.000000. mean reward 58.522842.
# World Perf: Episode 412.000000. Reward 32.000000. action: 0.000000. mean reward 58.171803.
# World Perf: Episode 415.000000. Reward 45.000000. action: 0.000000. mean reward 60.370296.
# World Perf: Episode 418.000000. Reward 76.333333. action: 1.000000. mean reward 60.218857.
# World Perf: Episode 421.000000. Reward 60.000000. action: 1.000000. mean reward 59.836193.
# World Perf: Episode 424.000000. Reward 41.333333. action: 1.000000. mean reward 61.997757.
# World Perf: Episode 427.000000. Reward 54.333333. action: 0.000000. mean reward 61.493896.
# World Perf: Episode 430.000000. Reward 40.666667. action: 0.000000. mean reward 63.683506.
# World Perf: Episode 433.000000. Reward 47.666667. action: 0.000000. mean reward 62.948273.
# World Perf: Episode 436.000000. Reward 31.333333. action: 0.000000. mean reward 62.295521.
# World Perf: Episode 439.000000. Reward 46.000000. action: 0.000000. mean reward 61.650356.
# World Perf: Episode 442.000000. Reward 49.000000. action: 1.000000. mean reward 63.859894.
# World Perf: Episode 445.000000. Reward 41.666667. action: 0.000000. mean reward 63.810062.
# World Perf: Episode 448.000000. Reward 43.000000. action: 1.000000. mean reward 65.221367.
# World Perf: Episode 451.000000. Reward 58.333333. action: 0.000000. mean reward 65.483269.
# World Perf: Episode 454.000000. Reward 39.666667. action: 0.000000. mean reward 64.752151.
# World Perf: Episode 457.000000. Reward 63.000000. action: 1.000000. mean reward 64.604774.
# World Perf: Episode 460.000000. Reward 53.333333. action: 1.000000. mean reward 64.166725.
# World Perf: Episode 463.000000. Reward 54.333333. action: 0.000000. mean reward 66.310814.
# World Perf: Episode 466.000000. Reward 60.333333. action: 1.000000. mean reward 68.556335.
# World Perf: Episode 469.000000. Reward 86.000000. action: 0.000000. mean reward 69.709908.
# World Perf: Episode 472.000000. Reward 44.666667. action: 1.000000. mean reward 69.276131.
# World Perf: Episode 475.000000. Reward 47.666667. action: 0.000000. mean reward 68.627113.
# World Perf: Episode 478.000000. Reward 58.666667. action: 1.000000. mean reward 68.661171.
# World Perf: Episode 481.000000. Reward 60.000000. action: 1.000000. mean reward 68.565086.
# World Perf: Episode 484.000000. Reward 35.666667. action: 0.000000. mean reward 70.605675.
# World Perf: Episode 487.000000. Reward 62.000000. action: 0.000000. mean reward 70.013840.
# World Perf: Episode 490.000000. Reward 58.333333. action: 1.000000. mean reward 69.439980.
# World Perf: Episode 493.000000. Reward 47.333333. action: 1.000000. mean reward 68.650154.
# World Perf: Episode 496.000000. Reward 49.333333. action: 0.000000. mean reward 68.056625.
# World Perf: Episode 499.000000. Reward 35.666667. action: 1.000000. mean reward 67.247978.
# World Perf: Episode 502.000000. Reward 68.000000. action: 0.000000. mean reward 66.678696.
# World Perf: Episode 505.000000. Reward 62.666667. action: 1.000000. mean reward 66.038971.
# World Perf: Episode 508.000000. Reward 32.000000. action: 0.000000. mean reward 65.112572.
# World Perf: Episode 511.000000. Reward 36.666667. action: 1.000000. mean reward 64.261757.
# World Perf: Episode 514.000000. Reward 45.000000. action: 1.000000. mean reward 63.486210.
# World Perf: Episode 517.000000. Reward 59.333333. action: 0.000000. mean reward 62.896412.
# World Perf: Episode 520.000000. Reward 60.666667. action: 0.000000. mean reward 62.745255.
# World Perf: Episode 523.000000. Reward 74.333333. action: 0.000000. mean reward 62.362457.
# World Perf: Episode 526.000000. Reward 58.666667. action: 1.000000. mean reward 61.757763.
# World Perf: Episode 529.000000. Reward 54.333333. action: 1.000000. mean reward 61.175522.
# World Perf: Episode 532.000000. Reward 55.666667. action: 1.000000. mean reward 60.996937.
# World Perf: Episode 535.000000. Reward 59.666667. action: 1.000000. mean reward 62.458965.
# World Perf: Episode 538.000000. Reward 70.666667. action: 1.000000. mean reward 62.287567.
# World Perf: Episode 541.000000. Reward 66.000000. action: 0.000000. mean reward 61.877636.
# World Perf: Episode 544.000000. Reward 63.000000. action: 1.000000. mean reward 64.157066.
# World Perf: Episode 547.000000. Reward 65.333333. action: 1.000000. mean reward 63.690540.
# World Perf: Episode 550.000000. Reward 100.000000. action: 1.000000. mean reward 63.577808.
# World Perf: Episode 553.000000. Reward 100.000000. action: 0.000000. mean reward 63.444424.
# World Perf: Episode 556.000000. Reward 85.000000. action: 1.000000. mean reward 65.556694.
# World Perf: Episode 559.000000. Reward 54.000000. action: 1.000000. mean reward 65.162643.
# World Perf: Episode 562.000000. Reward 46.000000. action: 1.000000. mean reward 64.439758.
# World Perf: Episode 565.000000. Reward 53.666667. action: 1.000000. mean reward 63.914173.
# World Perf: Episode 568.000000. Reward 85.666667. action: 0.000000. mean reward 65.600662.
# World Perf: Episode 571.000000. Reward 53.333333. action: 1.000000. mean reward 66.661797.
# World Perf: Episode 574.000000. Reward 48.333333. action: 0.000000. mean reward 66.762474.
# World Perf: Episode 577.000000. Reward 43.333333. action: 0.000000. mean reward 68.778641.
# World Perf: Episode 580.000000. Reward 60.000000. action: 1.000000. mean reward 68.410820.
# World Perf: Episode 583.000000. Reward 85.333333. action: 1.000000. mean reward 68.103706.
# World Perf: Episode 586.000000. Reward 81.666667. action: 0.000000. mean reward 67.827599.
# World Perf: Episode 589.000000. Reward 66.000000. action: 0.000000. mean reward 67.419067.
# World Perf: Episode 592.000000. Reward 48.333333. action: 0.000000. mean reward 66.707298.
# World Perf: Episode 595.000000. Reward 73.000000. action: 0.000000. mean reward 69.127571.
# World Perf: Episode 598.000000. Reward 66.666667. action: 1.000000. mean reward 69.417610.
# World Perf: Episode 601.000000. Reward 77.666667. action: 1.000000. mean reward 71.518410.
# World Perf: Episode 604.000000. Reward 80.000000. action: 1.000000. mean reward 73.074745.
# World Perf: Episode 607.000000. Reward 34.666667. action: 1.000000. mean reward 72.282570.
# World Perf: Episode 610.000000. Reward 42.666667. action: 1.000000. mean reward 72.859787.
# World Perf: Episode 613.000000. Reward 57.000000. action: 0.000000. mean reward 75.008080.
# World Perf: Episode 616.000000. Reward 57.000000. action: 0.000000. mean reward 74.363541.
# World Perf: Episode 619.000000. Reward 69.000000. action: 0.000000. mean reward 74.150604.
# World Perf: Episode 622.000000. Reward 68.666667. action: 0.000000. mean reward 74.469109.
# World Perf: Episode 625.000000. Reward 104.333333. action: 0.000000. mean reward 76.991188.
# World Perf: Episode 628.000000. Reward 68.333333. action: 0.000000. mean reward 76.400215.
# World Perf: Episode 631.000000. Reward 72.666667. action: 1.000000. mean reward 75.824089.
# World Perf: Episode 634.000000. Reward 92.666667. action: 0.000000. mean reward 76.362267.
# World Perf: Episode 637.000000. Reward 61.333333. action: 1.000000. mean reward 75.686867.
# World Perf: Episode 640.000000. Reward 82.000000. action: 0.000000. mean reward 77.527473.
# World Perf: Episode 643.000000. Reward 39.000000. action: 0.000000. mean reward 76.512100.
# World Perf: Episode 646.000000. Reward 66.666667. action: 0.000000. mean reward 76.158401.
# World Perf: Episode 649.000000. Reward 51.666667. action: 1.000000. mean reward 75.284782.
# World Perf: Episode 652.000000. Reward 71.000000. action: 1.000000. mean reward 74.657364.
# World Perf: Episode 655.000000. Reward 72.000000. action: 0.000000. mean reward 74.320396.
# World Perf: Episode 658.000000. Reward 64.000000. action: 1.000000. mean reward 73.633186.
# World Perf: Episode 661.000000. Reward 49.666667. action: 0.000000. mean reward 73.014061.
# World Perf: Episode 664.000000. Reward 81.666667. action: 1.000000. mean reward 72.522911.
# World Perf: Episode 667.000000. Reward 68.666667. action: 0.000000. mean reward 71.883530.
# World Perf: Episode 670.000000. Reward 47.666667. action: 1.000000. mean reward 71.098564.
# World Perf: Episode 673.000000. Reward 62.000000. action: 1.000000. mean reward 71.273262.
# World Perf: Episode 676.000000. Reward 65.333333. action: 0.000000. mean reward 71.737450.
# World Perf: Episode 679.000000. Reward 79.333333. action: 1.000000. mean reward 71.250969.
# World Perf: Episode 682.000000. Reward 55.333333. action: 0.000000. mean reward 70.469116.
# World Perf: Episode 685.000000. Reward 49.333333. action: 1.000000. mean reward 69.629555.
# World Perf: Episode 688.000000. Reward 63.666667. action: 1.000000. mean reward 68.946724.
# World Perf: Episode 691.000000. Reward 81.333333. action: 1.000000. mean reward 68.519272.
# World Perf: Episode 694.000000. Reward 93.000000. action: 1.000000. mean reward 68.380989.
# World Perf: Episode 697.000000. Reward 102.000000. action: 0.000000. mean reward 68.098961.
# World Perf: Episode 700.000000. Reward 42.666667. action: 1.000000. mean reward 67.630592.
# World Perf: Episode 703.000000. Reward 68.666667. action: 1.000000. mean reward 68.566063.
# World Perf: Episode 706.000000. Reward 75.000000. action: 1.000000. mean reward 68.192574.
# World Perf: Episode 709.000000. Reward 76.000000. action: 1.000000. mean reward 69.795815.
# World Perf: Episode 712.000000. Reward 53.000000. action: 1.000000. mean reward 69.137398.
# World Perf: Episode 715.000000. Reward 121.000000. action: 0.000000. mean reward 69.109306.
# World Perf: Episode 718.000000. Reward 85.000000. action: 1.000000. mean reward 69.618187.
# World Perf: Episode 721.000000. Reward 49.666667. action: 1.000000. mean reward 68.879875.
# World Perf: Episode 724.000000. Reward 62.000000. action: 1.000000. mean reward 68.429024.
# World Perf: Episode 727.000000. Reward 84.333333. action: 0.000000. mean reward 68.772591.
# World Perf: Episode 730.000000. Reward 60.000000. action: 0.000000. mean reward 68.110077.
# World Perf: Episode 733.000000. Reward 74.000000. action: 1.000000. mean reward 70.415138.
# World Perf: Episode 736.000000. Reward 78.000000. action: 0.000000. mean reward 72.136688.
# World Perf: Episode 739.000000. Reward 46.333333. action: 0.000000. mean reward 71.314415.
# World Perf: Episode 742.000000. Reward 54.666667. action: 0.000000. mean reward 73.336479.
# World Perf: Episode 745.000000. Reward 52.333333. action: 0.000000. mean reward 72.560036.
# World Perf: Episode 748.000000. Reward 93.000000. action: 1.000000. mean reward 72.250450.
# World Perf: Episode 751.000000. Reward 59.666667. action: 0.000000. mean reward 71.523155.
# World Perf: Episode 754.000000. Reward 58.333333. action: 0.000000. mean reward 72.744667.
# World Perf: Episode 757.000000. Reward 49.666667. action: 0.000000. mean reward 74.764297.
# World Perf: Episode 760.000000. Reward 38.333333. action: 0.000000. mean reward 74.046997.
# World Perf: Episode 763.000000. Reward 65.000000. action: 1.000000. mean reward 73.692322.
# World Perf: Episode 766.000000. Reward 96.666667. action: 1.000000. mean reward 73.417488.
# World Perf: Episode 769.000000. Reward 73.666667. action: 1.000000. mean reward 72.873543.
# World Perf: Episode 772.000000. Reward 85.333333. action: 0.000000. mean reward 72.543358.
# World Perf: Episode 775.000000. Reward 72.666667. action: 0.000000. mean reward 73.178696.
# World Perf: Episode 778.000000. Reward 55.333333. action: 1.000000. mean reward 74.468544.
# World Perf: Episode 781.000000. Reward 78.000000. action: 1.000000. mean reward 73.913368.
# World Perf: Episode 784.000000. Reward 59.000000. action: 1.000000. mean reward 73.129311.
# World Perf: Episode 787.000000. Reward 89.333333. action: 1.000000. mean reward 72.684639.
# World Perf: Episode 790.000000. Reward 37.000000. action: 0.000000. mean reward 71.852715.
# World Perf: Episode 793.000000. Reward 82.333333. action: 1.000000. mean reward 71.988686.
# World Perf: Episode 796.000000. Reward 43.000000. action: 0.000000. mean reward 71.302879.
# World Perf: Episode 799.000000. Reward 103.666667. action: 1.000000. mean reward 71.136406.
# World Perf: Episode 802.000000. Reward 81.666667. action: 1.000000. mean reward 70.729042.
# World Perf: Episode 805.000000. Reward 64.000000. action: 0.000000. mean reward 70.099480.
# World Perf: Episode 808.000000. Reward 80.666667. action: 0.000000. mean reward 69.678223.
# World Perf: Episode 811.000000. Reward 51.000000. action: 1.000000. mean reward 68.905945.
# World Perf: Episode 814.000000. Reward 50.666667. action: 0.000000. mean reward 68.365685.
# World Perf: Episode 817.000000. Reward 64.333333. action: 1.000000. mean reward 69.259712.
# World Perf: Episode 820.000000. Reward 84.000000. action: 1.000000. mean reward 70.593414.
# World Perf: Episode 823.000000. Reward 49.000000. action: 0.000000. mean reward 69.961792.
# World Perf: Episode 826.000000. Reward 94.333333. action: 0.000000. mean reward 69.682243.
# World Perf: Episode 829.000000. Reward 70.000000. action: 1.000000. mean reward 70.367050.
# World Perf: Episode 832.000000. Reward 48.000000. action: 0.000000. mean reward 69.579765.
# World Perf: Episode 835.000000. Reward 49.666667. action: 0.000000. mean reward 69.451576.
# World Perf: Episode 838.000000. Reward 69.666667. action: 0.000000. mean reward 71.732826.
# World Perf: Episode 841.000000. Reward 64.333333. action: 1.000000. mean reward 71.951637.
# World Perf: Episode 844.000000. Reward 62.000000. action: 0.000000. mean reward 71.465660.
# World Perf: Episode 847.000000. Reward 92.000000. action: 1.000000. mean reward 71.102814.
# World Perf: Episode 850.000000. Reward 61.666667. action: 0.000000. mean reward 70.617722.
# World Perf: Episode 853.000000. Reward 55.666667. action: 0.000000. mean reward 69.919746.
# World Perf: Episode 856.000000. Reward 71.333333. action: 1.000000. mean reward 72.281548.
# World Perf: Episode 859.000000. Reward 99.333333. action: 1.000000. mean reward 73.623711.
# World Perf: Episode 862.000000. Reward 70.666667. action: 0.000000. mean reward 75.830284.
# World Perf: Episode 865.000000. Reward 44.666667. action: 1.000000. mean reward 75.354988.
# World Perf: Episode 868.000000. Reward 73.000000. action: 1.000000. mean reward 74.717743.
# World Perf: Episode 871.000000. Reward 76.333333. action: 0.000000. mean reward 74.231544.
# World Perf: Episode 874.000000. Reward 58.666667. action: 1.000000. mean reward 73.475616.
# World Perf: Episode 877.000000. Reward 58.333333. action: 1.000000. mean reward 72.764534.
# World Perf: Episode 880.000000. Reward 90.000000. action: 1.000000. mean reward 73.155197.
# World Perf: Episode 883.000000. Reward 103.000000. action: 1.000000. mean reward 73.057381.
# World Perf: Episode 886.000000. Reward 73.000000. action: 1.000000. mean reward 75.107689.
# World Perf: Episode 889.000000. Reward 61.000000. action: 0.000000. mean reward 74.277534.
# World Perf: Episode 892.000000. Reward 69.666667. action: 1.000000. mean reward 74.411980.
# World Perf: Episode 895.000000. Reward 86.333333. action: 0.000000. mean reward 73.883606.
# World Perf: Episode 898.000000. Reward 94.000000. action: 0.000000. mean reward 73.439651.
# World Perf: Episode 901.000000. Reward 56.000000. action: 1.000000. mean reward 72.662079.
# World Perf: Episode 904.000000. Reward 47.000000. action: 0.000000. mean reward 71.779381.
# World Perf: Episode 907.000000. Reward 80.666667. action: 0.000000. mean reward 71.394318.
# World Perf: Episode 910.000000. Reward 55.666667. action: 0.000000. mean reward 73.279053.
# World Perf: Episode 913.000000. Reward 107.000000. action: 1.000000. mean reward 72.993767.
# World Perf: Episode 916.000000. Reward 69.333333. action: 1.000000. mean reward 72.384766.
# World Perf: Episode 919.000000. Reward 52.333333. action: 0.000000. mean reward 72.373344.
# World Perf: Episode 922.000000. Reward 94.666667. action: 0.000000. mean reward 72.070930.
# World Perf: Episode 925.000000. Reward 66.333333. action: 1.000000. mean reward 71.557457.
# World Perf: Episode 928.000000. Reward 70.000000. action: 0.000000. mean reward 71.175331.
# World Perf: Episode 931.000000. Reward 47.000000. action: 0.000000. mean reward 73.207230.
# World Perf: Episode 934.000000. Reward 66.666667. action: 0.000000. mean reward 75.347679.
# World Perf: Episode 937.000000. Reward 48.333333. action: 1.000000. mean reward 77.299484.
# World Perf: Episode 940.000000. Reward 76.333333. action: 1.000000. mean reward 76.751167.
# World Perf: Episode 943.000000. Reward 93.333333. action: 0.000000. mean reward 76.442604.
# World Perf: Episode 946.000000. Reward 91.666667. action: 1.000000. mean reward 76.005165.
# World Perf: Episode 949.000000. Reward 100.000000. action: 0.000000. mean reward 75.646477.
# World Perf: Episode 952.000000. Reward 57.000000. action: 1.000000. mean reward 74.882812.
# World Perf: Episode 955.000000. Reward 63.666667. action: 0.000000. mean reward 74.171791.
# World Perf: Episode 958.000000. Reward 118.666667. action: 0.000000. mean reward 74.697105.
# World Perf: Episode 961.000000. Reward 146.000000. action: 1.000000. mean reward 77.687019.
# World Perf: Episode 964.000000. Reward 77.000000. action: 0.000000. mean reward 79.854973.
# World Perf: Episode 967.000000. Reward 83.000000. action: 0.000000. mean reward 79.202515.
# World Perf: Episode 970.000000. Reward 92.333333. action: 1.000000. mean reward 78.690231.
# World Perf: Episode 973.000000. Reward 61.666667. action: 1.000000. mean reward 80.832664.
# World Perf: Episode 976.000000. Reward 112.666667. action: 0.000000. mean reward 80.940445.
# World Perf: Episode 979.000000. Reward 70.666667. action: 1.000000. mean reward 82.752151.
# World Perf: Episode 982.000000. Reward 77.333333. action: 0.000000. mean reward 85.087395.
# World Perf: Episode 985.000000. Reward 71.333333. action: 0.000000. mean reward 84.310295.
# World Perf: Episode 988.000000. Reward 82.000000. action: 0.000000. mean reward 83.570221.
# World Perf: Episode 991.000000. Reward 103.333333. action: 0.000000. mean reward 83.013451.
# World Perf: Episode 994.000000. Reward 81.333333. action: 0.000000. mean reward 82.227776.
# World Perf: Episode 997.000000. Reward 156.666667. action: 0.000000. mean reward 85.177742.
# World Perf: Episode 1000.000000. Reward 164.000000. action: 1.000000. mean reward 86.381920.
# World Perf: Episode 1003.000000. Reward 87.666667. action: 0.000000. mean reward 88.668846.
# World Perf: Episode 1006.000000. Reward 93.666667. action: 0.000000. mean reward 91.195839.
# World Perf: Episode 1009.000000. Reward 135.000000. action: 0.000000. mean reward 90.832184.
# World Perf: Episode 1012.000000. Reward 128.666667. action: 0.000000. mean reward 92.951439.
# World Perf: Episode 1015.000000. Reward 100.333333. action: 0.000000. mean reward 95.284882.
# World Perf: Episode 1018.000000. Reward 121.666667. action: 0.000000. mean reward 97.366302.
# World Perf: Episode 1021.000000. Reward 106.333333. action: 0.000000. mean reward 98.933601.
# World Perf: Episode 1024.000000. Reward 131.000000. action: 0.000000. mean reward 99.145149.
# World Perf: Episode 1027.000000. Reward 100.000000. action: 0.000000. mean reward 99.875061.
# World Perf: Episode 1030.000000. Reward 65.333333. action: 0.000000. mean reward 101.797943.
# World Perf: Episode 1033.000000. Reward 116.666667. action: 0.000000. mean reward 104.101288.
# World Perf: Episode 1036.000000. Reward 56.333333. action: 1.000000. mean reward 105.289307.
# World Perf: Episode 1039.000000. Reward 123.000000. action: 0.000000. mean reward 107.277199.
# World Perf: Episode 1042.000000. Reward 147.000000. action: 0.000000. mean reward 107.091423.
# World Perf: Episode 1045.000000. Reward 146.333333. action: 1.000000. mean reward 108.946831.
# World Perf: Episode 1048.000000. Reward 87.000000. action: 0.000000. mean reward 110.545319.
# World Perf: Episode 1051.000000. Reward 107.333333. action: 0.000000. mean reward 109.516777.
# World Perf: Episode 1054.000000. Reward 94.000000. action: 1.000000. mean reward 108.402290.
# World Perf: Episode 1057.000000. Reward 111.333333. action: 0.000000. mean reward 110.267365.
# World Perf: Episode 1060.000000. Reward 107.666667. action: 0.000000. mean reward 112.240974.
# World Perf: Episode 1063.000000. Reward 77.333333. action: 0.000000. mean reward 110.875420.
# World Perf: Episode 1066.000000. Reward 71.333333. action: 1.000000. mean reward 110.766457.
# World Perf: Episode 1069.000000. Reward 61.000000. action: 0.000000. mean reward 112.642998.
# World Perf: Episode 1072.000000. Reward 61.000000. action: 0.000000. mean reward 111.209106.
# World Perf: Episode 1075.000000. Reward 148.000000. action: 0.000000. mean reward 110.583977.
# World Perf: Episode 1078.000000. Reward 115.333333. action: 0.000000. mean reward 109.718689.
# World Perf: Episode 1081.000000. Reward 114.333333. action: 0.000000. mean reward 108.871216.
# World Perf: Episode 1084.000000. Reward 146.333333. action: 0.000000. mean reward 108.863411.
# World Perf: Episode 1087.000000. Reward 67.000000. action: 0.000000. mean reward 109.269470.
# World Perf: Episode 1090.000000. Reward 92.333333. action: 1.000000. mean reward 111.028465.
# World Perf: Episode 1093.000000. Reward 75.000000. action: 1.000000. mean reward 112.561455.
# World Perf: Episode 1096.000000. Reward 53.333333. action: 0.000000. mean reward 111.197479.
# World Perf: Episode 1099.000000. Reward 35.666667. action: 0.000000. mean reward 109.837898.
# World Perf: Episode 1102.000000. Reward 94.000000. action: 0.000000. mean reward 109.089439.
# World Perf: Episode 1105.000000. Reward 42.666667. action: 0.000000. mean reward 110.026863.
# World Perf: Episode 1108.000000. Reward 98.666667. action: 1.000000. mean reward 110.843620.
# World Perf: Episode 1111.000000. Reward 142.666667. action: 0.000000. mean reward 110.174736.
# World Perf: Episode 1114.000000. Reward 82.000000. action: 1.000000. mean reward 108.890800.
# World Perf: Episode 1117.000000. Reward 124.000000. action: 0.000000. mean reward 111.272514.
# World Perf: Episode 1120.000000. Reward 98.000000. action: 0.000000. mean reward 110.742958.
# World Perf: Episode 1123.000000. Reward 159.666667. action: 0.000000. mean reward 110.226311.
# World Perf: Episode 1126.000000. Reward 82.333333. action: 0.000000. mean reward 111.819221.
# World Perf: Episode 1129.000000. Reward 158.666667. action: 1.000000. mean reward 112.332848.
# World Perf: Episode 1132.000000. Reward 106.333333. action: 0.000000. mean reward 111.609184.
# World Perf: Episode 1135.000000. Reward 73.333333. action: 0.000000. mean reward 110.216896.
# World Perf: Episode 1138.000000. Reward 104.000000. action: 1.000000. mean reward 112.643524.
# World Perf: Episode 1141.000000. Reward 128.000000. action: 0.000000. mean reward 115.489532.
# World Perf: Episode 1144.000000. Reward 146.666667. action: 1.000000. mean reward 114.877625.
# World Perf: Episode 1147.000000. Reward 159.666667. action: 1.000000. mean reward 114.451820.
# World Perf: Episode 1150.000000. Reward 109.000000. action: 0.000000. mean reward 116.113258.
# World Perf: Episode 1153.000000. Reward 159.666667. action: 1.000000. mean reward 118.206207.
# World Perf: Episode 1156.000000. Reward 103.666667. action: 0.000000. mean reward 117.021355.
# World Perf: Episode 1159.000000. Reward 162.333333. action: 0.000000. mean reward 116.435188.
# World Perf: Episode 1162.000000. Reward 103.000000. action: 0.000000. mean reward 116.316071.
# World Perf: Episode 1165.000000. Reward 162.333333. action: 1.000000. mean reward 115.775414.
# World Perf: Episode 1168.000000. Reward 145.333333. action: 1.000000. mean reward 115.914848.
# World Perf: Episode 1171.000000. Reward 109.000000. action: 1.000000. mean reward 115.333519.
# World Perf: Episode 1174.000000. Reward 142.000000. action: 0.000000. mean reward 115.217735.
# World Perf: Episode 1177.000000. Reward 67.333333. action: 0.000000. mean reward 115.786034.
# World Perf: Episode 1180.000000. Reward 74.000000. action: 0.000000. mean reward 114.481010.
# World Perf: Episode 1183.000000. Reward 94.333333. action: 0.000000. mean reward 114.282478.
# World Perf: Episode 1186.000000. Reward 73.333333. action: 0.000000. mean reward 115.729530.
# World Perf: Episode 1189.000000. Reward 161.333333. action: 0.000000. mean reward 115.763641.
# World Perf: Episode 1192.000000. Reward 100.333333. action: 0.000000. mean reward 115.141075.
# World Perf: Episode 1195.000000. Reward 107.666667. action: 0.000000. mean reward 114.095215.
# World Perf: Episode 1198.000000. Reward 91.000000. action: 0.000000. mean reward 113.249542.
# World Perf: Episode 1201.000000. Reward 129.333333. action: 0.000000. mean reward 113.423981.
# World Perf: Episode 1204.000000. Reward 147.333333. action: 0.000000. mean reward 115.474182.
# World Perf: Episode 1207.000000. Reward 70.333333. action: 1.000000. mean reward 114.151215.
# World Perf: Episode 1210.000000. Reward 152.333333. action: 1.000000. mean reward 114.435158.
# World Perf: Episode 1213.000000. Reward 112.000000. action: 0.000000. mean reward 116.283264.
# World Perf: Episode 1216.000000. Reward 110.666667. action: 0.000000. mean reward 118.037590.
# World Perf: Episode 1219.000000. Reward 151.000000. action: 0.000000. mean reward 117.387505.
# World Perf: Episode 1222.000000. Reward 118.666667. action: 1.000000. mean reward 116.556053.
# World Perf: Episode 1225.000000. Reward 109.666667. action: 1.000000. mean reward 118.261848.
# World Perf: Episode 1228.000000. Reward 129.000000. action: 0.000000. mean reward 119.354744.
# World Perf: Episode 1231.000000. Reward 88.666667. action: 0.000000. mean reward 119.713692.
# World Perf: Episode 1234.000000. Reward 116.666667. action: 0.000000. mean reward 121.415916.
# World Perf: Episode 1237.000000. Reward 118.000000. action: 1.000000. mean reward 123.133476.
# World Perf: Episode 1240.000000. Reward 100.333333. action: 1.000000. mean reward 123.040657.
# World Perf: Episode 1243.000000. Reward 69.000000. action: 0.000000. mean reward 123.572395.
# World Perf: Episode 1246.000000. Reward 165.666667. action: 0.000000. mean reward 125.908134.
# World Perf: Episode 1249.000000. Reward 121.666667. action: 0.000000. mean reward 125.001289.
# World Perf: Episode 1252.000000. Reward 95.333333. action: 0.000000. mean reward 124.248604.
# World Perf: Episode 1255.000000. Reward 127.000000. action: 1.000000. mean reward 126.396538.
# World Perf: Episode 1258.000000. Reward 168.666667. action: 0.000000. mean reward 125.997162.
# World Perf: Episode 1261.000000. Reward 81.333333. action: 0.000000. mean reward 125.557549.
# World Perf: Episode 1264.000000. Reward 123.333333. action: 0.000000. mean reward 127.510071.
# World Perf: Episode 1267.000000. Reward 109.000000. action: 0.000000. mean reward 126.266724.
# World Perf: Episode 1270.000000. Reward 134.333333. action: 0.000000. mean reward 126.396248.
# World Perf: Episode 1273.000000. Reward 121.333333. action: 1.000000. mean reward 126.845970.
# World Perf: Episode 1276.000000. Reward 71.333333. action: 0.000000. mean reward 125.233025.
# World Perf: Episode 1279.000000. Reward 103.666667. action: 0.000000. mean reward 123.978203.
# World Perf: Episode 1282.000000. Reward 124.000000. action: 0.000000. mean reward 123.260864.
# World Perf: Episode 1285.000000. Reward 116.666667. action: 0.000000. mean reward 122.636772.
# World Perf: Episode 1288.000000. Reward 113.000000. action: 0.000000. mean reward 121.729607.
# World Perf: Episode 1291.000000. Reward 196.333333. action: 0.000000. mean reward 124.217232.
# World Perf: Episode 1294.000000. Reward 79.333333. action: 0.000000. mean reward 125.535400.
# World Perf: Episode 1297.000000. Reward 176.666667. action: 0.000000. mean reward 125.237892.
# World Perf: Episode 1300.000000. Reward 156.000000. action: 1.000000. mean reward 124.738182.
# World Perf: Episode 1303.000000. Reward 118.333333. action: 0.000000. mean reward 125.767700.
# World Perf: Episode 1306.000000. Reward 127.666667. action: 0.000000. mean reward 124.669762.
# World Perf: Episode 1309.000000. Reward 142.666667. action: 0.000000. mean reward 125.954918.
# World Perf: Episode 1312.000000. Reward 108.666667. action: 0.000000. mean reward 125.146400.
# World Perf: Episode 1315.000000. Reward 142.000000. action: 0.000000. mean reward 124.248657.
# World Perf: Episode 1318.000000. Reward 130.666667. action: 0.000000. mean reward 126.275749.
# World Perf: Episode 1321.000000. Reward 168.333333. action: 0.000000. mean reward 128.352951.
# World Perf: Episode 1324.000000. Reward 119.000000. action: 0.000000. mean reward 127.293724.
# World Perf: Episode 1327.000000. Reward 149.333333. action: 1.000000. mean reward 128.478195.
# World Perf: Episode 1330.000000. Reward 104.666667. action: 1.000000. mean reward 127.224815.
# World Perf: Episode 1333.000000. Reward 75.333333. action: 0.000000. mean reward 128.472702.
# World Perf: Episode 1336.000000. Reward 162.333333. action: 1.000000. mean reward 130.550491.
# World Perf: Episode 1339.000000. Reward 106.666667. action: 1.000000. mean reward 131.504593.
# World Perf: Episode 1342.000000. Reward 159.000000. action: 0.000000. mean reward 130.699539.
# World Perf: Episode 1345.000000. Reward 166.333333. action: 0.000000. mean reward 130.823944.
# World Perf: Episode 1348.000000. Reward 141.333333. action: 0.000000. mean reward 132.604538.
# World Perf: Episode 1351.000000. Reward 125.666667. action: 0.000000. mean reward 133.531967.
# World Perf: Episode 1354.000000. Reward 102.000000. action: 1.000000. mean reward 134.563614.
# World Perf: Episode 1357.000000. Reward 200.000000. action: 1.000000. mean reward 134.489456.
# World Perf: Episode 1360.000000. Reward 121.666667. action: 1.000000. mean reward 135.980743.
# World Perf: Episode 1363.000000. Reward 167.000000. action: 1.000000. mean reward 136.343613.
# World Perf: Episode 1366.000000. Reward 180.000000. action: 1.000000. mean reward 135.632507.
# World Perf: Episode 1369.000000. Reward 166.000000. action: 1.000000. mean reward 137.494339.
# World Perf: Episode 1372.000000. Reward 109.000000. action: 0.000000. mean reward 138.796005.
# World Perf: Episode 1375.000000. Reward 130.666667. action: 0.000000. mean reward 139.575180.
# World Perf: Episode 1378.000000. Reward 117.333333. action: 0.000000. mean reward 140.570663.
# World Perf: Episode 1381.000000. Reward 114.000000. action: 1.000000. mean reward 140.634720.
# World Perf: Episode 1384.000000. Reward 149.666667. action: 0.000000. mean reward 142.326431.
# World Perf: Episode 1387.000000. Reward 180.333333. action: 1.000000. mean reward 144.403900.
# World Perf: Episode 1390.000000. Reward 120.666667. action: 0.000000. mean reward 145.875107.
# World Perf: Episode 1393.000000. Reward 116.000000. action: 1.000000. mean reward 147.334122.
# World Perf: Episode 1396.000000. Reward 124.333333. action: 0.000000. mean reward 147.844727.
# World Perf: Episode 1399.000000. Reward 167.666667. action: 1.000000. mean reward 147.531265.
# World Perf: Episode 1402.000000. Reward 198.333333. action: 0.000000. mean reward 148.259460.
# World Perf: Episode 1405.000000. Reward 149.000000. action: 0.000000. mean reward 149.013458.
# World Perf: Episode 1408.000000. Reward 124.333333. action: 0.000000. mean reward 150.268677.
# World Perf: Episode 1411.000000. Reward 140.666667. action: 1.000000. mean reward 151.644577.
# World Perf: Episode 1414.000000. Reward 166.333333. action: 0.000000. mean reward 153.175674.
# World Perf: Episode 1417.000000. Reward 149.666667. action: 1.000000. mean reward 154.609421.
# World Perf: Episode 1420.000000. Reward 181.333333. action: 0.000000. mean reward 155.801361.
# World Perf: Episode 1423.000000. Reward 147.000000. action: 0.000000. mean reward 157.158859.
# World Perf: Episode 1426.000000. Reward 170.000000. action: 1.000000. mean reward 158.703140.
# World Perf: Episode 1429.000000. Reward 196.666667. action: 1.000000. mean reward 160.284286.
# World Perf: Episode 1432.000000. Reward 132.666667. action: 1.000000. mean reward 161.576767.
# World Perf: Episode 1435.000000. Reward 115.666667. action: 1.000000. mean reward 161.024887.
# World Perf: Episode 1438.000000. Reward 165.000000. action: 1.000000. mean reward 161.615372.
# World Perf: Episode 1441.000000. Reward 164.000000. action: 0.000000. mean reward 163.046600.
# World Perf: Episode 1444.000000. Reward 130.000000. action: 0.000000. mean reward 161.522461.
# World Perf: Episode 1447.000000. Reward 171.666667. action: 1.000000. mean reward 162.802872.
# World Perf: Episode 1450.000000. Reward 135.000000. action: 0.000000. mean reward 163.877975.
# World Perf: Episode 1453.000000. Reward 198.666667. action: 0.000000. mean reward 164.986862.
# World Perf: Episode 1456.000000. Reward 167.333333. action: 0.000000. mean reward 165.415131.
# World Perf: Episode 1459.000000. Reward 85.333333. action: 1.000000. mean reward 164.668961.
# World Perf: Episode 1462.000000. Reward 172.666667. action: 0.000000. mean reward 163.590302.
# World Perf: Episode 1465.000000. Reward 123.000000. action: 0.000000. mean reward 162.078201.
# World Perf: Episode 1468.000000. Reward 164.000000. action: 0.000000. mean reward 161.936798.
# World Perf: Episode 1471.000000. Reward 175.666667. action: 0.000000. mean reward 163.167953.
# World Perf: Episode 1474.000000. Reward 172.333333. action: 0.000000. mean reward 162.461334.
# World Perf: Episode 1477.000000. Reward 172.333333. action: 1.000000. mean reward 161.939072.
# World Perf: Episode 1480.000000. Reward 153.666667. action: 0.000000. mean reward 160.484421.
# World Perf: Episode 1483.000000. Reward 200.000000. action: 1.000000. mean reward 162.275620.
# World Perf: Episode 1486.000000. Reward 148.000000. action: 1.000000. mean reward 160.964340.
# World Perf: Episode 1489.000000. Reward 166.333333. action: 0.000000. mean reward 162.421555.
# World Perf: Episode 1492.000000. Reward 147.000000. action: 0.000000. mean reward 163.630203.
# World Perf: Episode 1495.000000. Reward 154.333333. action: 1.000000. mean reward 163.052032.
# World Perf: Episode 1498.000000. Reward 165.333333. action: 0.000000. mean reward 161.824814.
# World Perf: Episode 1501.000000. Reward 155.666667. action: 0.000000. mean reward 163.137680.
# World Perf: Episode 1504.000000. Reward 188.333333. action: 0.000000. mean reward 164.745804.
# World Perf: Episode 1507.000000. Reward 169.000000. action: 0.000000. mean reward 163.724106.
# World Perf: Episode 1510.000000. Reward 170.000000. action: 0.000000. mean reward 165.161942.
# World Perf: Episode 1513.000000. Reward 175.000000. action: 0.000000. mean reward 166.619370.
# World Perf: Episode 1516.000000. Reward 200.000000. action: 0.000000. mean reward 167.517960.
# World Perf: Episode 1519.000000. Reward 198.666667. action: 0.000000. mean reward 169.145187.
# World Perf: Episode 1522.000000. Reward 190.000000. action: 0.000000. mean reward 168.040329.
# World Perf: Episode 1525.000000. Reward 140.333333. action: 1.000000. mean reward 166.529160.
# World Perf: Episode 1528.000000. Reward 152.333333. action: 1.000000. mean reward 165.125595.
# World Perf: Episode 1531.000000. Reward 200.000000. action: 1.000000. mean reward 164.097946.
# World Perf: Episode 1534.000000. Reward 153.666667. action: 0.000000. mean reward 165.373062.
# World Perf: Episode 1537.000000. Reward 137.333333. action: 0.000000. mean reward 166.447479.
# World Perf: Episode 1540.000000. Reward 170.333333. action: 0.000000. mean reward 166.355545.
# World Perf: Episode 1543.000000. Reward 158.666667. action: 0.000000. mean reward 167.607498.
# World Perf: Episode 1546.000000. Reward 173.333333. action: 1.000000. mean reward 168.978302.
# World Perf: Episode 1549.000000. Reward 125.000000. action: 0.000000. mean reward 169.912643.
# World Perf: Episode 1552.000000. Reward 200.000000. action: 1.000000. mean reward 171.501175.
# World Perf: Episode 1555.000000. Reward 173.333333. action: 0.000000. mean reward 172.767639.
# World Perf: Episode 1558.000000. Reward 181.666667. action: 0.000000. mean reward 172.005569.
# World Perf: Episode 1561.000000. Reward 128.333333. action: 0.000000. mean reward 170.225006.
# World Perf: Episode 1564.000000. Reward 192.333333. action: 0.000000. mean reward 171.676773.
# ...
# World Perf: Episode 2044.000000. Reward 200.000000. action: 1.000000. mean reward 184.429764.
# World Perf: Episode 2047.000000. Reward 200.000000. action: 1.000000. mean reward 185.708450.
# World Perf: Episode 2050.000000. Reward 200.000000. action: 0.000000. mean reward 186.974289.
# World Perf: Episode 2053.000000. Reward 200.000000. action: 1.000000. mean reward 188.157852.
# World Perf: Episode 2056.000000. Reward 200.000000. action: 0.000000. mean reward 189.324341.
# World Perf: Episode 2059.000000. Reward 200.000000. action: 0.000000. mean reward 190.480286.
# World Perf: Episode 2062.000000. Reward 200.000000. action: 1.000000. mean reward 191.614624.
# World Perf: Episode 2065.000000. Reward 200.000000. action: 0.000000. mean reward 192.754318.
# World Perf: Episode 2068.000000. Reward 200.000000. action: 1.000000. mean reward 193.904617.
# World Perf: Episode 2071.000000. Reward 192.000000. action: 0.000000. mean reward 194.921341.
# World Perf: Episode 2074.000000. Reward 200.000000. action: 0.000000. mean reward 195.957230.
# World Perf: Episode 2077.000000. Reward 200.000000. action: 0.000000. mean reward 197.644455.
# World Perf: Episode 2080.000000. Reward 200.000000. action: 0.000000. mean reward 198.501358.
# World Perf: Episode 2083.000000. Reward 183.000000. action: 1.000000. mean reward 199.203751.
# World Perf: Episode 2086.000000. Reward 200.000000. action: 0.000000. mean reward 200.337784.
# World Perf: Episode 2089.000000. Reward 200.000000. action: 0.000000. mean reward 201.032333.
# World Perf: Episode 2092.000000. Reward 195.000000. action: 1.000000. mean reward 199.153397.
# World Perf: Episode 2095.000000. Reward 200.000000. action: 0.000000. mean reward 198.057449.
# World Perf: Episode 2098.000000. Reward 200.000000. action: 1.000000. mean reward 196.227890.
# World Perf: Episode 2101.000000. Reward 200.000000. action: 0.000000. mean reward 194.554932.
# World Perf: Episode 2104.000000. Reward 200.000000. action: 1.000000. mean reward 192.847244.
# World Perf: Episode 2107.000000. Reward 200.000000. action: 1.000000. mean reward 194.174850.
# World Perf: Episode 2110.000000. Reward 200.000000. action: 0.000000. mean reward 195.172195.
# World Perf: Episode 2113.000000. Reward 200.000000. action: 0.000000. mean reward 196.130783.
# World Perf: Episode 2116.000000. Reward 200.000000. action: 1.000000. mean reward 195.411179.
# World Perf: Episode 2119.000000. Reward 200.000000. action: 1.000000. mean reward 193.811844.
# World Perf: Episode 2122.000000. Reward 200.000000. action: 0.000000. mean reward 194.069092.
# World Perf: Episode 2125.000000. Reward 200.000000. action: 0.000000. mean reward 195.382401.
# World Perf: Episode 2128.000000. Reward 200.000000. action: 0.000000. mean reward 193.912094.
# World Perf: Episode 2131.000000. Reward 200.000000. action: 1.000000. mean reward 195.105957.
# World Perf: Episode 2134.000000. Reward 200.000000. action: 0.000000. mean reward 196.169937.
# World Perf: Episode 2137.000000. Reward 200.000000. action: 0.000000. mean reward 196.343201.
# World Perf: Episode 2140.000000. Reward 200.000000. action: 0.000000. mean reward 197.424911.
# World Perf: Episode 2143.000000. Reward 200.000000. action: 1.000000. mean reward 195.936707.
# World Perf: Episode 2146.000000. Reward 200.000000. action: 1.000000. mean reward 197.034348.
# World Perf: Episode 2149.000000. Reward 200.000000. action: 0.000000. mean reward 195.810837.
# World Perf: Episode 2152.000000. Reward 200.000000. action: 0.000000. mean reward 196.106461.
# World Perf: Episode 2155.000000. Reward 200.000000. action: 1.000000. mean reward 195.590408.
# World Perf: Episode 2158.000000. Reward 200.000000. action: 0.000000. mean reward 194.935623.
# World Perf: Episode 2161.000000. Reward 200.000000. action: 0.000000. mean reward 196.104874.
# World Perf: Episode 2164.000000. Reward 200.000000. action: 1.000000. mean reward 197.192261.
# World Perf: Episode 2167.000000. Reward 200.000000. action: 0.000000. mean reward 198.271957.
# World Perf: Episode 2170.000000. Reward 200.000000. action: 0.000000. mean reward 199.053528.
# World Perf: Episode 2173.000000. Reward 200.000000. action: 1.000000. mean reward 200.035843.
# World Perf: Episode 2176.000000. Reward 200.000000. action: 0.000000. mean reward 200.103561.
# World Perf: Episode 2179.000000. Reward 200.000000. action: 1.000000. mean reward 201.162827.
# World Perf: Episode 2182.000000. Reward 200.000000. action: 0.000000. mean reward 201.459167.
# World Perf: Episode 2185.000000. Reward 188.333333. action: 0.000000. mean reward 199.945786.
# World Perf: Episode 2188.000000. Reward 200.000000. action: 0.000000. mean reward 201.201950.
# World Perf: Episode 2191.000000. Reward 200.000000. action: 0.000000. mean reward 200.629074.
# World Perf: Episode 2194.000000. Reward 200.000000. action: 1.000000. mean reward 200.103134.
# World Perf: Episode 2197.000000. Reward 200.000000. action: 1.000000. mean reward 198.313889.
# World Perf: Episode 2200.000000. Reward 200.000000. action: 0.000000. mean reward 196.895737.
# World Perf: Episode 2203.000000. Reward 200.000000. action: 1.000000. mean reward 195.451492.
# World Perf: Episode 2206.000000. Reward 200.000000. action: 1.000000. mean reward 194.065903.
# World Perf: Episode 2209.000000. Reward 200.000000. action: 0.000000. mean reward 194.182022.
# World Perf: Episode 2212.000000. Reward 200.000000. action: 1.000000. mean reward 195.280640.
# World Perf: Episode 2215.000000. Reward 200.000000. action: 0.000000. mean reward 195.435104.
# World Perf: Episode 2218.000000. Reward 200.000000. action: 1.000000. mean reward 195.821548.
# World Perf: Episode 2221.000000. Reward 200.000000. action: 1.000000. mean reward 196.855576.
# World Perf: Episode 2224.000000. Reward 200.000000. action: 0.000000. mean reward 195.434570.
# World Perf: Episode 2227.000000. Reward 200.000000. action: 1.000000. mean reward 194.030640.
# World Perf: Episode 2230.000000. Reward 200.000000. action: 1.000000. mean reward 193.892227.
# World Perf: Episode 2233.000000. Reward 200.000000. action: 0.000000. mean reward 195.048477.
# World Perf: Episode 2236.000000. Reward 200.000000. action: 0.000000. mean reward 194.302078.
# World Perf: Episode 2239.000000. Reward 200.000000. action: 0.000000. mean reward 194.046143.
# World Perf: Episode 2242.000000. Reward 200.000000. action: 0.000000. mean reward 195.133926.
# World Perf: Episode 2245.000000. Reward 200.000000. action: 1.000000. mean reward 196.194351.
# World Perf: Episode 2248.000000. Reward 200.000000. action: 1.000000. mean reward 197.277161.
# World Perf: Episode 2251.000000. Reward 200.000000. action: 0.000000. mean reward 196.217514.
# World Perf: Episode 2254.000000. Reward 200.000000. action: 1.000000. mean reward 197.257675.
# World Perf: Episode 2257.000000. Reward 200.000000. action: 1.000000. mean reward 198.297684.
# World Perf: Episode 2260.000000. Reward 200.000000. action: 0.000000. mean reward 197.086990.
# World Perf: Episode 2263.000000. Reward 200.000000. action: 0.000000. mean reward 195.847946.
# World Perf: Episode 2266.000000. Reward 200.000000. action: 0.000000. mean reward 196.933426.
# World Perf: Episode 2269.000000. Reward 200.000000. action: 1.000000. mean reward 195.502060.
# World Perf: Episode 2272.000000. Reward 200.000000. action: 0.000000. mean reward 196.647095.
# World Perf: Episode 2275.000000. Reward 192.000000. action: 0.000000. mean reward 195.484085.
# World Perf: Episode 2278.000000. Reward 200.000000. action: 0.000000. mean reward 193.827103.
# World Perf: Episode 2281.000000. Reward 200.000000. action: 1.000000. mean reward 194.894699.
# World Perf: Episode 2284.000000. Reward 200.000000. action: 0.000000. mean reward 194.329697.
# World Perf: Episode 2287.000000. Reward 200.000000. action: 0.000000. mean reward 194.496399.
# World Perf: Episode 2290.000000. Reward 200.000000. action: 1.000000. mean reward 195.632706.
# World Perf: Episode 2293.000000. Reward 200.000000. action: 0.000000. mean reward 196.744263.
# World Perf: Episode 2296.000000. Reward 200.000000. action: 0.000000. mean reward 197.046890.
# World Perf: Episode 2299.000000. Reward 200.000000. action: 0.000000. mean reward 197.459091.
# World Perf: Episode 2302.000000. Reward 200.000000. action: 0.000000. mean reward 197.932785.
# World Perf: Episode 2305.000000. Reward 200.000000. action: 0.000000. mean reward 197.631592.
# World Perf: Episode 2308.000000. Reward 200.000000. action: 0.000000. mean reward 199.160477.
# World Perf: Episode 2311.000000. Reward 192.000000. action: 0.000000. mean reward 199.718918.
# World Perf: Episode 2314.000000. Reward 200.000000. action: 0.000000. mean reward 200.217941.
# World Perf: Episode 2317.000000. Reward 200.000000. action: 0.000000. mean reward 201.017883.
# World Perf: Episode 2320.000000. Reward 200.000000. action: 1.000000. mean reward 199.452499.
# World Perf: Episode 2323.000000. Reward 200.000000. action: 0.000000. mean reward 200.456100.
# World Perf: Episode 2326.000000. Reward 200.000000. action: 0.000000. mean reward 201.486801.
# World Perf: Episode 2329.000000. Reward 200.000000. action: 0.000000. mean reward 200.811142.
# World Perf: Episode 2332.000000. Reward 200.000000. action: 1.000000. mean reward 200.155350.
# World Perf: Episode 2335.000000. Reward 200.000000. action: 1.000000. mean reward 199.658737.
# World Perf: Episode 2338.000000. Reward 200.000000. action: 0.000000. mean reward 198.616638.
# World Perf: Episode 2341.000000. Reward 200.000000. action: 1.000000. mean reward 199.617142.
# World Perf: Episode 2344.000000. Reward 200.000000. action: 0.000000. mean reward 200.618652.
# World Perf: Episode 2347.000000. Reward 200.000000. action: 1.000000. mean reward 200.173447.
# World Perf: Episode 2350.000000. Reward 200.000000. action: 1.000000. mean reward 201.159348.
# World Perf: Episode 2353.000000. Reward 200.000000. action: 0.000000. mean reward 201.601303.
# World Perf: Episode 2356.000000. Reward 200.000000. action: 0.000000. mean reward 202.499985.
# World Perf: Episode 2359.000000. Reward 200.000000. action: 1.000000. mean reward 201.682617.
# World Perf: Episode 2362.000000. Reward 200.000000. action: 0.000000. mean reward 202.623596.
# World Perf: Episode 2365.000000. Reward 200.000000. action: 1.000000. mean reward 203.569168.
# World Perf: Episode 2368.000000. Reward 200.000000. action: 0.000000. mean reward 203.865601.
# World Perf: Episode 2371.000000. Reward 200.000000. action: 1.000000. mean reward 202.617538.
# World Perf: Episode 2374.000000. Reward 200.000000. action: 1.000000. mean reward 201.086594.
# World Perf: Episode 2377.000000. Reward 200.000000. action: 1.000000. mean reward 199.660095.
# World Perf: Episode 2380.000000. Reward 200.000000. action: 1.000000. mean reward 198.148026.
# World Perf: Episode 2383.000000. Reward 200.000000. action: 1.000000. mean reward 196.489792.
# World Perf: Episode 2386.000000. Reward 200.000000. action: 0.000000. mean reward 195.744141.
# World Perf: Episode 2389.000000. Reward 200.000000. action: 0.000000. mean reward 194.982727.
# World Perf: Episode 2392.000000. Reward 200.000000. action: 1.000000. mean reward 195.767746.
# World Perf: Episode 2395.000000. Reward 200.000000. action: 1.000000. mean reward 196.845016.
# World Perf: Episode 2398.000000. Reward 200.000000. action: 0.000000. mean reward 197.888596.
# World Perf: Episode 2401.000000. Reward 199.000000. action: 0.000000. mean reward 198.896744.
# World Perf: Episode 2404.000000. Reward 185.666667. action: 1.000000. mean reward 199.798279.
# World Perf: Episode 2407.000000. Reward 200.000000. action: 1.000000. mean reward 199.809036.
# World Perf: Episode 2410.000000. Reward 200.000000. action: 0.000000. mean reward 200.266724.
# World Perf: Episode 2413.000000. Reward 193.333333. action: 1.000000. mean reward 200.455917.
# World Perf: Episode 2416.000000. Reward 200.000000. action: 1.000000. mean reward 201.503799.
# World Perf: Episode 2419.000000. Reward 162.000000. action: 1.000000. mean reward 202.314514.
# World Perf: Episode 2422.000000. Reward 200.000000. action: 1.000000. mean reward 203.593246.
# World Perf: Episode 2425.000000. Reward 200.000000. action: 0.000000. mean reward 203.788986.
# World Perf: Episode 2428.000000. Reward 200.000000. action: 1.000000. mean reward 201.948715.
# World Perf: Episode 2431.000000. Reward 200.000000. action: 0.000000. mean reward 200.021835.
# World Perf: Episode 2434.000000. Reward 200.000000. action: 1.000000. mean reward 200.112167.
# World Perf: Episode 2437.000000. Reward 188.333333. action: 0.000000. mean reward 199.145325.
# World Perf: Episode 2440.000000. Reward 194.333333. action: 1.000000. mean reward 200.551147.
# World Perf: Episode 2443.000000. Reward 200.000000. action: 1.000000. mean reward 201.530411.
# World Perf: Episode 2446.000000. Reward 200.000000. action: 1.000000. mean reward 202.486267.
# World Perf: Episode 2449.000000. Reward 164.333333. action: 1.000000. mean reward 203.153015.
# World Perf: Episode 2452.000000. Reward 200.000000. action: 1.000000. mean reward 204.109924.
# World Perf: Episode 2455.000000. Reward 173.333333. action: 0.000000. mean reward 204.724808.
# World Perf: Episode 2458.000000. Reward 200.000000. action: 1.000000. mean reward 204.452759.
# World Perf: Episode 2461.000000. Reward 200.000000. action: 0.000000. mean reward 204.031845.
# World Perf: Episode 2464.000000. Reward 199.333333. action: 1.000000. mean reward 202.753662.
# World Perf: Episode 2467.000000. Reward 192.333333. action: 0.000000. mean reward 202.327042.
# World Perf: Episode 2470.000000. Reward 200.000000. action: 0.000000. mean reward 201.572327.
# World Perf: Episode 2473.000000. Reward 200.000000. action: 0.000000. mean reward 200.460632.
# World Perf: Episode 2476.000000. Reward 173.000000. action: 0.000000. mean reward 201.171127.
# World Perf: Episode 2479.000000. Reward 200.000000. action: 1.000000. mean reward 201.066711.
# World Perf: Episode 2482.000000. Reward 187.333333. action: 0.000000. mean reward 201.556564.
# World Perf: Episode 2485.000000. Reward 200.000000. action: 1.000000. mean reward 201.498596.
# World Perf: Episode 2488.000000. Reward 170.666667. action: 0.000000. mean reward 199.811234.
# World Perf: Episode 2491.000000. Reward 200.000000. action: 1.000000. mean reward 198.319260.
# World Perf: Episode 2494.000000. Reward 200.000000. action: 1.000000. mean reward 196.982346.
# World Perf: Episode 2497.000000. Reward 200.000000. action: 1.000000. mean reward 195.575928.
# World Perf: Episode 2500.000000. Reward 200.000000. action: 0.000000. mean reward 194.308472.
# World Perf: Episode 2503.000000. Reward 200.000000. action: 0.000000. mean reward 195.355667.
# World Perf: Episode 2506.000000. Reward 191.000000. action: 1.000000. mean reward 195.620117.
# World Perf: Episode 2509.000000. Reward 200.000000. action: 1.000000. mean reward 195.151016.
# World Perf: Episode 2512.000000. Reward 200.000000. action: 0.000000. mean reward 195.411682.
# World Perf: Episode 2515.000000. Reward 199.000000. action: 1.000000. mean reward 196.469925.
# World Perf: Episode 2518.000000. Reward 200.000000. action: 0.000000. mean reward 197.561417.
# World Perf: Episode 2521.000000. Reward 200.000000. action: 0.000000. mean reward 198.576584.
# World Perf: Episode 2524.000000. Reward 200.000000. action: 1.000000. mean reward 199.582764.
# World Perf: Episode 2527.000000. Reward 200.000000. action: 0.000000. mean reward 200.591232.
# World Perf: Episode 2530.000000. Reward 200.000000. action: 1.000000. mean reward 201.569092.
# World Perf: Episode 2533.000000. Reward 200.000000. action: 1.000000. mean reward 202.497864.
# World Perf: Episode 2536.000000. Reward 200.000000. action: 1.000000. mean reward 203.417343.
# World Perf: Episode 2539.000000. Reward 189.000000. action: 1.000000. mean reward 203.964615.
# World Perf: Episode 2542.000000. Reward 200.000000. action: 0.000000. mean reward 204.625732.
# World Perf: Episode 2545.000000. Reward 200.000000. action: 0.000000. mean reward 205.514481.
# World Perf: Episode 2548.000000. Reward 200.000000. action: 0.000000. mean reward 206.421738.
# World Perf: Episode 2551.000000. Reward 200.000000. action: 0.000000. mean reward 207.320312.
# 2551

# %% [markdown]
# ### Checking model representation
# Here we can examine how well the model is able to approximate the true environment after training. The green line indicates the real environment, and the blue indicates model predictions.

# %%
plt.figure(figsize=(8, 12))
for i in range(6):
    plt.subplot(6, 2, 2*i + 1)
    plt.plot(pState[:,i])
    plt.subplot(6,2,2*i+1)
    plt.plot(state_nextsAll[:,i])
plt.tight_layout()
